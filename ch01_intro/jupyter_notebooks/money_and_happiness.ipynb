# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

# %%
pwd
# Out:
# 'C:\\Users\\Erik\\Documents\\Projects\\Tutorials\\repos\\machine_learning\\Ch01_Intro'

# %%
# Load data
oecd_bli = pd.read_csv(r"./data/2017_OECD_better_life_index.csv", usecols=['Country', 'Value'])

# %%
oecd_bli.head()
# Out:
#           Country  Value
# 0       Australia    4.3
# 1         Austria    2.7
# 2         Belgium    4.8
# 3          Canada    3.9
# 4  Czech Republic    1.8

# %%
gdp_per_capita = pd.read_csv(r"./data/AllYears_imf_gdp_per_capita.csv", usecols=['GDP per capita, current prices (U.S. dollars per capita)', '2017'])

# %%
pd.merge(left=gdp_per_capita, right=oecd_bli, left_on='GDP per capita, current prices (U.S. dollars per capita)', right_on='Country')
# Out:
#      GDP per capita, current prices (U.S. dollars per capita)       2017  \
# 0                                             Australia        56135.416
# 1                                             Australia        56135.416
# 2                                             Australia        56135.416
# 3                                             Australia        56135.416
# 4                                             Australia        56135.416
# 5                                             Australia        56135.416
# 6                                             Australia        56135.416
# 7                                             Australia        56135.416
# 8                                             Australia        56135.416
# 9                                             Australia        56135.416
# 10                                            Australia        56135.416
# 11                                            Australia        56135.416
# ...

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2017": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]
